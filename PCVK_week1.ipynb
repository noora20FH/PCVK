# %% [markdown]
# <a href="https://colab.research.google.com/github/noora20FH/PCVK/blob/main/PCVK_week1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
from skimage import transform
from PIL import Image
import matplotlib.pylab as plt

#create list to store image urls
urls = ["https://iiif.lib.ncsu.edu/iiif/0052574/full/800,/0/default.jpg","https://iiif.lib.ncsu.edu/iiif/0016007/full/800,/0/default.jpg","https://placekitten.com/800/571"]

#read and show image
#loop every url image, several image can be stored in a list
for url in urls:
  image = io.imread(url)
  image = cv. resize(image, (0,0), fx=0.5, fy=0.5)
  image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
  final_frame = cv.hconcat((image, image_2))
  cv2_imshow(final_frame)
  print('\n')
# Out:
# <PIL.Image.Image image mode=RGB size=800x276 at 0x7F794F5C1940>
# <PIL.Image.Image image mode=RGB size=800x286 at 0x7F7920F0ED00>
# <PIL.Image.Image image mode=RGB size=800x286 at 0x7F794F5C1700>

# %%
tinggi = image_2.shape[0]
lebar = image_2.shape[1]
print("reslusi image: tinggixlebar = ", tinggi,' x ', lebar)
cv2_imshow(image_2)
# Out:
# reslusi image: tinggixlebar =  286  x  400
# <PIL.Image.Image image mode=RGB size=400x286 at 0x7F7917D807C0>

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

#create horizontal line in the middle of the image
for y in range(lebar):
  image_3[int((tinggi)/2),y] = [255,255,255]

# image_3[int((tinggi)/2),10:100] = [255,255,255]
final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286 at 0x7F7917C90C70>

# %% [markdown]
# Question
# 1. Explain why in this practicum module the execution of Python code is done using
# Google Colab?
# 2. Explain the use of each library in the eighth step practicum? Do all these libraries haveto be used in this practical session?
# 3. In the 8th step of the experiment there is a snippet of program code as follows:
# What is the use of the program code ? and what is the effect if it is not done?
# 4. Take a look at the following program code snippet:
# What is the use of the code [255,255,255] ? Explain!
# 5. Explain the relationship between pixels and high or low image resolution!
#
# Answer
# 1. because google collab able to connect to the github, also we can easily share our code through link github or google collab
# 2. so far, we still don't need some of it
# ......
# 3. the use is to resize the mage to be a half size from the original.
# unless we resize the original image, the image is shown as the original and it's bigger than this
# 4. without iteration we can immediately iterate the process of giving with color for pixel on a half of its height and along the width
# 5.
