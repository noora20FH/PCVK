# %% [markdown]
# <a href="https://colab.research.google.com/github/noora20FH/PCVK/blob/week12/week12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# NOORA AULIA HIDAYAT
#
# 2041720046
#
# https://github.com/noora20FH/PCVK/blob/week12/week12.ipynb

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install --upgrade opencv-python
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (4.7.0.72)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.10/dist-packages (from opencv-python) (1.22.4)

# %%
import cv2 as cv

cascade_wajah = cv.CascadeClassifier('/content/drive/MyDrive/haarcascade_frontalface_alt.xml')

img = cv.imread('/content/drive/MyDrive/jokowi.jpg')

# Convert the image to grayscale
gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)

faces = cascade_wajah.detectMultiScale(gray, 1.3, 5)
for (x, y, w, h) in faces:
    cv.rectangle(img, (x, y), (x+w, y+h), (255, 0, 0), 2)
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = img[y:y+h, x:x+w]

cv.imshow('img', img)
cv.waitKey(0)
cv.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-4-a3d87178fb14> in <cell line: 10>()
#       8 gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)
#       9
# ---> 10 faces = cascade_wajah.detectMultiScale(gray, 1.3, 5)
#      11 for (x, y, w, h) in faces:
#      12     cv.rectangle(img, (x, y), (x+w, y+h), (255, 0, 0), 2)
#
# error: OpenCV(4.7.0) /io/opencv/modules/objdetect/src/cascadedetect.cpp:1689: error: (-215:Assertion failed) !empty() in function 'detectMultiScale'

# %%
import cv2 as cv
import numpy as np
from matplotlib import pyplot as plt

# %%
cascade_wajah = cv.CascadeClassifier('/content/drive/MyDrive/haarcascade_frontalface_alt.xml')

# %%
img = cv.imread('/content/drive/MyDrive/jokowi.jpg')

plt.subplot(221), plt.imshow(cv.cvtColor(img, cv.COLOR_BGR2RGB))
plt.title('Input Image'), plt.axis('off')

# Convert the images to grayscale
img_gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)

# %%
faces = cascade_wajah.detectMultiScale(img_gray, 1.3, 5)
for (x,y,w,h) in faces:
    cv.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = img[y:y+h, x:x+w]

cv.imshow('img',img)
cv.waitKey(0)
cv.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-17-930cd6cba9c0> in <cell line: 1>()
# ----> 1 faces = cascade_wajah.detectMultiScale(img_gray, 1.3, 5)
#       2 for (x,y,w,h) in faces:
#       3     cv.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
#       4     roi_gray = gray[y:y+h, x:x+w]
#       5     roi_color = img[y:y+h, x:x+w]
#
# error: OpenCV(4.7.0) /io/opencv/modules/objdetect/src/cascadedetect.cpp:1689: error: (-215:Assertion failed) !empty() in function 'detectMultiScale'

# %%
# Display the input image, template image, matching result, and detected point
sift = cv.SIFT_create()
kp = sift.detect(img_gray,None)
img=cv.drawKeypoints(img_gray,kp,img)
plt.subplot(224), plt.imshow(cv.cvtColor(img, cv.COLOR_BGR2RGB))
# plt.title('Detected Point'), plt.axis('off')
# plt.scatter(top_left[0], top_left[1], color='r', marker='x')
plt.show()
