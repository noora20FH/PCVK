# %% [markdown]
# <a href="https://colab.research.google.com/github/noora20FH/PCVK/blob/week12/week12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# NOORA AULIA HIDAYAT
#
# 2041720046
#
# https://github.com/noora20FH/PCVK/blob/week12/week12.ipynb

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install --upgrade opencv-python
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import cv2 as cv
from matplotlib import pyplot as plt

# %% [markdown]
# #Task 1

# %%
cascade_wajah = cv.CascadeClassifier('/content/drive/MyDrive/haarcascade_frontalface_alt2.xml')

img = cv.imread('/content/drive/MyDrive/jokowi.jpg')

plt.subplot(221), plt.imshow(cv.cvtColor(img, cv.COLOR_BGR2RGB))
plt.title('Input Image'), plt.axis('off')

# Convert the image to grayscale
gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)

faces = cascade_wajah.detectMultiScale(gray, 1.3, 5)
for (x, y, w, h) in faces:
    cv.rectangle(img, (x, y), (x+w, y+h), (0, 255, 0), 5)
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = img[y:y+h, x:x+w]

# Display the input image with rectangles around the detected faces
plt.subplot(222), plt.imshow(cv.cvtColor(img, cv.COLOR_BGR2RGB))
plt.title('Detected Faces'), plt.axis('off')

faces = cascade_wajah.detectMultiScale(gray, 1.3, 5)
for (x, y, w, h) in faces:
    cv.rectangle(gray, (x, y), (x+w, y+h), (255, 0, 0), 5)
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = img[y:y+h, x:x+w]

# Display the input image with rectangles around the detected faces
plt.subplot(224), plt.imshow(gray, cmap='gray')
plt.title('Detected Faces'), plt.axis('off')

plt.show()

# %%
cascade_wajah = cv.CascadeClassifier('/content/drive/MyDrive/haarcascade_frontalface_alt2.xml')

img = cv.imread('/content/drive/MyDrive/kartini.jpg')

plt.subplot(221), plt.imshow(cv.cvtColor(img, cv.COLOR_BGR2RGB))
plt.title('Input Image'), plt.axis('off')

# Convert the image to grayscale
gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)

faces = cascade_wajah.detectMultiScale(gray, 1.3, 5)
for (x, y, w, h) in faces:
    cv.rectangle(img, (x, y), (x+w, y+h), (0, 255, 0), 5)
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = img[y:y+h, x:x+w]

# Display the input image with rectangles around the detected faces
plt.subplot(222), plt.imshow(cv.cvtColor(img, cv.COLOR_BGR2RGB))
plt.title('Detected Faces'), plt.axis('off')



plt.show()

# %%
cascade_wajah = cv.CascadeClassifier('/content/drive/MyDrive/haarcascade_frontalface_alt2.xml')

img = cv.imread('/content/drive/MyDrive/kucing.jpg')

plt.subplot(221), plt.imshow(cv.cvtColor(img, cv.COLOR_BGR2RGB))
plt.title('Input Image'), plt.axis('off')

# Convert the image to grayscale
gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)

faces = cascade_wajah.detectMultiScale(gray, 1.3, 5)
for (x, y, w, h) in faces:
    cv.rectangle(img, (x, y), (x+w, y+h), (0, 255, 0), 5)
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = img[y:y+h, x:x+w]

# Display the input image with rectangles around the detected faces
plt.subplot(222), plt.imshow(cv.cvtColor(img, cv.COLOR_BGR2RGB))
plt.title('Detected Faces'), plt.axis('off')


plt.show()

# %%
cascade_wajah = cv.CascadeClassifier('/content/drive/MyDrive/haarcascade_frontalface_default.xml')

img = cv.imread('/content/drive/MyDrive/mask.png')

plt.subplot(221), plt.imshow(cv.cvtColor(img, cv.COLOR_BGR2RGB))
plt.title('Input Image'), plt.axis('off')

# Convert the image to grayscale
gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)

faces = cascade_wajah.detectMultiScale(gray, 1.3, 5)
for (x, y, w, h) in faces:
    cv.rectangle(img, (x, y), (x+w, y+h), (0, 255, 0), 5)
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = img[y:y+h, x:x+w]

# Display the input image with rectangles around the detected faces
plt.subplot(222), plt.imshow(cv.cvtColor(img, cv.COLOR_BGR2RGB))
plt.title('Detected Faces'), plt.axis('off')



plt.show()

# %%
cascade_wajah = cv.CascadeClassifier('/content/drive/MyDrive/haarcascade_frontalface_alt.xml')

img = cv.imread('/content/drive/MyDrive/mjordan.jpg')

plt.subplot(221), plt.imshow(cv.cvtColor(img, cv.COLOR_BGR2RGB))
plt.title('Input Image'), plt.axis('off')

# Convert the image to grayscale
gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)

faces = cascade_wajah.detectMultiScale(gray, 1.3, 5)
for (x, y, w, h) in faces:
    cv.rectangle(img, (x, y), (x+w, y+h), (0, 255, 0), 5)
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = img[y:y+h, x:x+w]

# Display the input image with rectangles around the detected faces
plt.subplot(222), plt.imshow(cv.cvtColor(img, cv.COLOR_BGR2RGB))
plt.title('Detected Faces'), plt.axis('off')



plt.show()

# %% [markdown]
# github source: https://github.com/opencv/opencv/tree/master/data/haarcascades

# %%
cascade_wajah = cv.CascadeClassifier('/content/drive/MyDrive/haarcascade_frontalface_alt.xml')

img = cv.imread('/content/drive/MyDrive/solvayconf.jpg')

plt.subplot(221), plt.imshow(cv.cvtColor(img, cv.COLOR_BGR2RGB))
plt.title('Input Image'), plt.axis('off')

# Convert the image to grayscale
gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)

faces = cascade_wajah.detectMultiScale(gray, 1.3, 5)
for (x, y, w, h) in faces:
    cv.rectangle(img, (x, y), (x+w, y+h), (0, 255, 0), 5)
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = img[y:y+h, x:x+w]

# Display the input image with rectangles around the detected faces
plt.subplot(222), plt.imshow(cv.cvtColor(img, cv.COLOR_BGR2RGB))
plt.title('Detected Faces'), plt.axis('off')



plt.show()

# %% [markdown]
# #Task 2
# In Problem No.2. cat faces cannot be detected properly. Detect the cat's face until a
# rectangle appears on the face. For instructions on this problem, pay attention to the
# pretrained features that OpenCV has provided. Use the existing xml if one is provided.
# If you don't have it, try searching by searching through search engines

# %%
cascade_wajah = cv.CascadeClassifier('/content/drive/MyDrive/haarcascade_frontalcatface.xml')

img = cv.imread('/content/drive/MyDrive/kucing.jpg')

plt.subplot(221), plt.imshow(cv.cvtColor(img, cv.COLOR_BGR2RGB))
plt.title('Input Image'), plt.axis('off')

# Convert the image to grayscale
gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)

faces = cascade_wajah.detectMultiScale(gray, 1.3, 5)
for (x, y, w, h) in faces:
    cv.rectangle(img, (x, y), (x+w, y+h), (0, 255, 0), 5)
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = img[y:y+h, x:x+w]

# Display the input image with rectangles around the detected faces
plt.subplot(222), plt.imshow(cv.cvtColor(img, cv.COLOR_BGR2RGB))
plt.title('Detected Faces'), plt.axis('off')


plt.show()

# %% [markdown]
# #Task 3
# Also try it for an eyes detection

# %%
cascade_wajah = cv.CascadeClassifier('/content/drive/MyDrive/haarcascade_righteye_2splits.xml')
cascade_wajah2 = cv.CascadeClassifier('/content/drive/MyDrive/haarcascade_lefteye_2splits.xml')

img = cv.imread('/content/drive/MyDrive/jokowi.jpg')

plt.subplot(221), plt.imshow(cv.cvtColor(img, cv.COLOR_BGR2RGB))
plt.title('Input Image'), plt.axis('off')

# Convert the image to grayscale
gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)



faces = cascade_wajah.detectMultiScale(gray, 1.3, 5)
for (x, y, w, h) in faces:
    cv.rectangle(gray, (x, y), (x+w, y+h), (255, 0, 0), 5)
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = img[y:y+h, x:x+w]

faces_ = cascade_wajah2.detectMultiScale(gray, 1.3, 5)
for (x, y, w, h) in faces_:
    cv.rectangle(gray, (x, y), (x+w, y+h), (255, 0, 0), 5)
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = img[y:y+h, x:x+w]

# Display the input image with rectangles around the detected faces
plt.subplot(222), plt.imshow(gray, cmap='gray')
plt.title('Detected Faces'), plt.axis('off')

plt.show()

# %% [markdown]
# #Task 4
# Implement Face Tracking using Google Colab. Instructions, complete tutorials on camera
# access and FaceDetection on google colab can be seen at the following
# link: https://www.youtube.com/watch?v=YjWh7QvVH60

# %% [markdown]
# #Task 5
#
# Blur the detected part of the face. Here's an example of the output. Hint: you can use
# cv.medianBlur to give a blur effect

# %%
import cv2 as cv
from matplotlib import pyplot as plt

cascade_wajah = cv.CascadeClassifier('/content/drive/MyDrive/haarcascade_frontalface_alt.xml')

img = cv.imread('/content/drive/MyDrive/mjordan.jpg')

plt.subplot(221), plt.imshow(cv.cvtColor(img, cv.COLOR_BGR2RGB))
plt.title('Input Image'), plt.axis('off')

# Convert the image to grayscale
gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)

faces = cascade_wajah.detectMultiScale(gray, 1.3, 5)
for (x, y, w, h) in faces:
    
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = img[y:y+h, x:x+w]
    blurred_roi = cv.medianBlur(roi_gray, 25)  # Apply median blur to the detected region
    gray[y:y+h, x:x+w] = blurred_roi

# Display the input image with rectangles around the detected faces and blurred regions
plt.subplot(222), plt.imshow(cv.cvtColor(gray, cv.COLOR_BGR2RGB))
plt.title('Detected Faces (Blurred)'), plt.axis('off')

plt.show()
