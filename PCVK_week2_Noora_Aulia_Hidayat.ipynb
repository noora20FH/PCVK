# %% [markdown]
# <a href="https://colab.research.google.com/github/noora20FH/PCVK/blob/week2/PCVK_week2_Noora_Aulia_Hidayat.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #PRACTICUM

# %%
from google.colab import drive

#Access my google drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
img = cv.imread('/content/drive/MyDrive/Foto3x4.jpg')
plt.imshow(img)

# %%
img2 = img
img3 = cv.cvtColor(img,cv.COLOR_BGR2RGB)
plt.imshow(img3)

# %% [markdown]
# #Coloring

# %%
img_gray = cv.imread('/content/drive/MyDrive/Foto3x4.jpg', cv.IMREAD_GRAYSCALE) 
plt.imshow(img_gray)

# %%
plt.imshow(img_gray, cmap='gray')

# %%
plt.imshow(img_gray, cmap='magma')

# %% [markdown]
# #Resizing

# %%
img4 = cv.resize(cv.cvtColor(img,cv.COLOR_BGR2RGB), (512,1024))
plt.imshow(img4)

# %%
# Show the bigger canvas on the plot, 
img5 = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB), 0)
fig = plt.figure(figsize=(10,10)) #we can change the size value other than (10,10)
ax = fig.add_subplot(111)
ax.imshow(img5)

# %% [markdown]
# #Creating 2D image

# %%
black_image
# Out:
# reslusi image: tinggixlebar =  286  x  400
# <PIL.Image.Image image mode=RGB size=400x286 at 0x7F4B86AF3250>

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

#create horizontal line in the middle of the image
for x in range(tinggi):
  image_3[x,lebar-40] = [255,255,255]

# image_3[int((tinggi)/2),10:100] = [255,255,255]
final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)


# explanation:
# x = tinggi
# y = lebar
# the value of x changes from 0 to 286
# the value of y is constant, which is 400 - pixel index[40]
# Out:
# <PIL.Image.Image image mode=RGB size=800x286 at 0x7F4B66DCDAC0>

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

#create horizontal line in the middle of the image
for y in range(lebar):
  image_3[tinggi - 70,y] = [255,255,255]

# image_3[int((tinggi)/2),10:100] = [255,255,255]
final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)

# explanation
# the y changes from 0 to 400
# the x is constant which is 286 - pixel index[70]
# Out:
# <PIL.Image.Image image mode=RGB size=800x286 at 0x7F4062354160>

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

#create horizontal line in the middle of the image
for x in range(tinggi):
  image_3[x ,x] = [255,255,255]
  image_3[x,y-1-x] = [255,255,255]

# image_3[int((tinggi)/2),10:100] = [255,255,255]
final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286 at 0x7F4B1A7B5EB0>

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

var = (lebar/tinggi)
#create horizontal line in the middle of the image
for x in range(tinggi):

  image_3[x,int(x*var)] = [255,255,255]
  image_3[x,lebar-1-int(x*var)] = [255,255,255]


final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286 at 0x7F4B1A78D7F0>

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

#create horizontal line in the middle of the image
for y in range(lebar):
  image_3[int((tinggi)/2),y] = [255,255,255]

# image_3[int((tinggi)/2),10:100] = [255,255,255]
final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286 at 0x7F99A4513310>

# %% [markdown]
# Question
# 1. Explain why in this practicum module the execution of Python code is done using Google Colab?
# 2. Explain the use of each library in the eighth step practicum? Do all these libraries haveto be used in this practical session?
# 3. In the 8th step of the experiment there is a snippet of program code as follows:
# What is the use of the program code ? and what is the effect if it is not done?
# 4. Take a look at the following program code snippet:
# create horizontal line in the middle of the image
# for y in range(lebar):
#   image_3[int((tinggi)/2),y] = [255,255,255]
# What is the use of the code [255,255,255] ? Explain!
# 5. Explain the relationship between pixels and high or low image resolution!
#
# Answer
# 1. because google collab able to connect to the github, also we can easily share our code through link github or google collab
#
# 2. Numpy = an array manipulation library, used for linear algebra,fourier transform, and random number capabilities
# Pandas = library for data manipulation and data analisys
# CV = for computer vision tasks
# skimage = support image processing application in pyhton
# matplotlib = generates figures and provides graphical user interface toolkiit.
# PIL = Python Imaging Library  is a free and open-source additional library for the Python programming language that adds support for opening, manipulating, and saving many different image file formats.
#
# so far, we still haven't use all of those library. we only use some of them such as CV2, skimage, and PIL
#
# 3. the use is to resize the image to be a half size from the original.
# unless we resize the original image, the image is shown as the original and it's bigger than this.
#
# 4. without iteration we can immediately iterate the process of giving with color for pixel on a half of its height and along the width. the code [255, 255, 255] it's a RGB color of white. we define the color of pixel that's located on image_3[int((tinggi)/2),y]
#
# 5. the image that is high resolution has clear appearence, no blur, even the pixel we can't see it. Higher resolutions mean that there more pixels per inch (PPI), resulting in more pixel information and creating a high-quality, crisp image. Images with lower resolutions have fewer pixels, and if those few pixels are too large the pixel can become visible.

# %% [markdown]
# #TASK

# %% [markdown]
# ##1. Do the practical steps as above

# %% [markdown]
# ##2. Create vertical lines and diagonal lines in the output image

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

#create horizontal line in the middle of the image
for x in range(tinggi):
  image_3[x,int((lebar)/2)] = [255,255,255]

# image_3[int((tinggi)/2),10:100] = [255,255,255]
final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286 at 0x7F9960E5DA30>

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

#create horizontal line in the middle of the image
# for x in range(tinggi):
#   image_3[x,int((lebar)/2)] = [255,255,255]

# image_3[int((tinggi)/2),10:100] = [255,255,255]

img = cv.line(image_3, (0,0), (lebar, tinggi), (255,255,255), 1)
            #(the_image, (start_point_top_left), (width,height), (B,G,R_lineColor), line_thicknese)
#create another line that crossing the first line
img = cv.line(img, (0,tinggi), (lebar, 0), (255,255,255), 1)

final_frame = cv.hconcat((image_2, img))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286 at 0x7F9957529190>

# %% [markdown]
# ##3. Draw the horizontal white lines in the middle of image with certain length

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

#create horizontal line in the middle of the image


image_3[int((tinggi)/2),50:250] = [255,255,255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286 at 0x7F9957529F70>

# %% [markdown]
# ##4. Draw a box from a collection of white pixel in certain area in the image

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

#create horizontal line in the middle of the image


image_3[30:80,100:250] = [255,255,255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286 at 0x7F995D281AC0>
